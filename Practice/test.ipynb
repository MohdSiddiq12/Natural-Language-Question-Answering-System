# %%
import joblib

# %%
model = joblib.load('C:/Users/MohdS/OneDrive/Desktop/Major-Project/bert_qa_custom.joblib')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = joblib.load('C:/Users/MohdS/OneDrive/Desktop/Major-Project/bert_qa_custom.joblib')
#
# File c:\Users\MohdS\anaconda3\lib\site-packages\joblib\numpy_pickle.py:587, in load(filename, mmap_mode)
#     581             if isinstance(fobj, str):
#     582                 # if the returned file object is a string, this means we
#     583                 # try to load a pickle file generated with an version of
#     584                 # Joblib so we load it with joblib compatibility function.
#     585                 return load_compatibility(fobj)
# --> 587             obj = _unpickle(fobj, filename, mmap_mode)
#     588 return obj
#
# File c:\Users\MohdS\anaconda3\lib\site-packages\joblib\numpy_pickle.py:506, in _unpickle(fobj, filename, mmap_mode)
#     504 obj = None
#     505 try:
# ...
